# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
url="https://raw.githubusercontent.com/janMelisa055/entrega_1/main/american_bankruptcy.csv"
df = pd.read_csv(url)
df.head()
# Out:
#   company_name status_label  year       X1       X2      X3      X4       X5  \
# 0          C_1        alive  1999  511.267  833.107  18.373  89.031  336.018
# 1          C_1        alive  2000  485.856  713.811  18.577  64.367  320.590
# 2          C_1        alive  2001  436.656  526.477  22.496  27.207  286.588
# 3          C_1        alive  2002  396.412  496.747  27.172  30.745  259.954
# 4          C_1        alive  2003  432.204  523.302  26.680  47.491  247.245
#
#        X6       X7  ...        X9      X10      X11     X12      X13      X14  \
# 0  35.163  128.348  ...  1024.333  740.998  180.447  70.658  191.226  163.816
# 1  18.531  115.187  ...   874.255  701.854  179.987  45.790  160.444  125.392
# 2 -58.939   77.528  ...   638.721  710.199  217.699   4.711  112.244  150.464
# 3 -12.410   66.322  ...   606.337  686.621  164.658   3.573  109.590  203.575
# 4   3.504  104.661  ...   651.958  709.292  248.666  20.811  128.656  131.261
#
# ...

# %%
# Cambio de nombre de columnas.
df.rename(columns = {
    "X1": "Activos Corrientes",
    "X2": "Costo de Bienes Vendidos",
    "X3": "Depreciación y Amortización",
    "X4": "EBITDA",
    "X5": "Inventario",
    "X6": "Ingresos Netos",
    "X7": "Cuentas por Cobrar",
    "X8": "Valor de Mercado",
    "X9": "Ventas Netas",
    "X10": "Activos Totales",
    "X11": "Deuda a Largo Plazo Total",
    "X12": "EBIT",
    "X13": "Ganancias Brutas",
    "X14": "Pasivos Corrientes",
    "X15": "Ganancias Retenidas",
    "X16": "Ganancias Totales",
    "X17": "Pasivos Totales",
    "X18": "Costo Operativo Total"
    }, inplace = True)

# Eliminar compañías.
try:
  df = df.drop(["company_name"], axis = 1)
except:
  print("Ya se corrió línea de código.")

# Partir df en 2.
midpoint = len(df.columns) // 2

df1 = df.iloc[:, :midpoint]
df2 = df.iloc[:, midpoint:]

# %%
df1.head()
# Out:
#   status_label  year  Activos Corrientes  Costo de Bienes Vendidos  \
# 0        alive  1999             511.267                   833.107
# 1        alive  2000             485.856                   713.811
# 2        alive  2001             436.656                   526.477
# 3        alive  2002             396.412                   496.747
# 4        alive  2003             432.204                   523.302
#
#    Depreciación y Amortización  EBITDA  Inventario  Ingresos Netos  \
# 0                       18.373  89.031     336.018          35.163
# 1                       18.577  64.367     320.590          18.531
# 2                       22.496  27.207     286.588         -58.939
# 3                       27.172  30.745     259.954         -12.410
# 4                       26.680  47.491     247.245           3.504
#
#    Cuentas por Cobrar  Valor de Mercado
# 0             128.348          372.7519
# 1             115.187          377.1180
# ...

# %%
df2.head()
# Out:
#    Ventas Netas  Activos Totales  Deuda a Largo Plazo Total    EBIT  \
# 0      1024.333          740.998                    180.447  70.658
# 1       874.255          701.854                    179.987  45.790
# 2       638.721          710.199                    217.699   4.711
# 3       606.337          686.621                    164.658   3.573
# 4       651.958          709.292                    248.666  20.811
#
#    Ganancias Brutas  Pasivos Corrientes  Ganancias Retenidas  \
# 0           191.226             163.816              201.026
# 1           160.444             125.392              204.065
# 2           112.244             150.464              139.603
# 3           109.590             203.575              124.106
# 4           128.656             131.261              131.884
#
#    Ganancias Totales  Pasivos Totales  Costo Operativo Total
# 0           1024.333          401.483                935.302
# 1            874.255          361.642                809.888
# ...

# %%
df1.describe().applymap("{:,.2f}".format).replace(",", "", regex=True)
# Out:
# <ipython-input-76-b99fa39e05c6>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df1.describe().applymap("{:,.2f}".format).replace(",", "", regex=True)
#            year Activos Corrientes Costo de Bienes Vendidos  \
# count  78682.00           78682.00                 78682.00
# mean    2007.51             880.36                  1594.53
# std        5.74            3928.56                  8930.48
# min     1999.00              -7.76                  -366.64
# 25%     2002.00              18.92                    17.04
# 50%     2007.00             100.45                   103.66
# 75%     2012.00             431.53                   634.55
# max     2018.00          169662.00                374623.00
#
#       Depreciación y Amortización     EBITDA Inventario Ingresos Netos  \
# count                    78682.00   78682.00   78682.00       78682.00
# mean                       121.23     376.76     201.61         129.38
# ...

# %%
df2.describe().applymap("{:,.2f}".format).replace(",", " ", regex=True)
# Out:
# <ipython-input-77-366137bc319c>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2.describe().applymap("{:,.2f}".format).replace(",", "", regex=True)
#       Ventas Netas Activos Totales Deuda a Largo Plazo Total       EBIT  \
# count     78682.00        78682.00                  78682.00   78682.00
# mean       2364.02         2867.11                    722.48     255.53
# std       11950.07        12917.94                   3242.17    1494.64
# min       -1965.00            0.00                     -0.02  -25913.00
# 25%          27.55           37.36                      0.00      -2.79
# 50%         186.60          213.20                      7.59       6.52
# 75%        1046.40         1171.36                    248.76      87.60
# max      511729.00       531864.00                 166250.00   71230.00
#
#       Ganancias Brutas Pasivos Corrientes Ganancias Retenidas  \
# count         78682.00           78682.00            78682.00
# ...
